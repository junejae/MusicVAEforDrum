# %% [markdown]
# # 1. Magenta 설치

# %%
# !pip install magenta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting magenta
#   Downloading magenta-2.1.4-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 7.6 MB/s
# Collecting note-seq==0.0.3
#   Downloading note_seq-0.0.3-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 68.1 MB/s
# Requirement already satisfied: scipy==1.7.3 in /usr/local/lib/python3.7/dist-packages (from magenta) (1.7.3)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: wheel==0.37.1 in /usr/local/lib/python3.7/dist-packages (from magenta) (0.37.1)
# Collecting pygtrie==2.5.0
#   Downloading pygtrie-2.5.0.tar.gz (39 kB)
# Collecting Pillow==9.2.0
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 53.6 MB/s
# Collecting tensorflow-probability==0.17.0
#   Downloading tensorflow_probability-0.17.0-py2.py3-none-any.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 43.5 MB/s
# Collecting sk-video==1.1.10
#   Downloading sk_video-1.1.10-py2.py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 47.7 MB/s
# Collecting tensorflow==2.9.1
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 6.4 kB/s
# Collecting sox==1.4.1
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting matplotlib==3.5.2
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 57.2 MB/s
# Collecting tf-slim==1.1.0
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 71.3 MB/s
# Collecting pretty-midi==0.2.9
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 16.2 MB/s
# Collecting mir-eval==0.7
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#      |████████████████████████████████| 90 kB 11.6 MB/s
# Collecting python-rtmidi==1.1.2
#   Downloading python-rtmidi-1.1.2.tar.gz (204 kB)
#      |████████████████████████████████| 204 kB 69.0 MB/s
# Collecting librosa==0.7.2
#   Downloading librosa-0.7.2.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 49.5 MB/s
# Requirement already satisfied: absl-py==1.2.0 in /usr/local/lib/python3.7/dist-packages (from magenta) (1.2.0)
# Collecting numba==0.49.1
#   Downloading numba-0.49.1-cp37-cp37m-manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 61.1 MB/s
# Collecting scikit-image==0.19.3
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 46.9 MB/s
# Collecting mido==1.2.6
#   Downloading mido-1.2.6-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 9.2 MB/s
# Requirement already satisfied: numpy==1.21.6 in /usr/local/lib/python3.7/dist-packages (from magenta) (1.21.6)
# Requirement already satisfied: tensorflow-datasets==4.6.0 in /usr/local/lib/python3.7/dist-packages (from magenta) (4.6.0)
# Collecting imageio==2.20.0
#   Downloading imageio-2.20.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 52.9 MB/s
# Collecting dm-sonnet==2.0.0
#   Downloading dm_sonnet-2.0.0-py3-none-any.whl (254 kB)
#      |████████████████████████████████| 254 kB 77.1 MB/s
# Requirement already satisfied: dm-tree>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from dm-sonnet==2.0.0->magenta) (0.1.7)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from dm-sonnet==2.0.0->magenta) (1.14.1)
# Requirement already satisfied: tabulate>=0.7.5 in /usr/local/lib/python3.7/dist-packages (from dm-sonnet==2.0.0->magenta) (0.8.10)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.2->magenta) (2.1.9)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.2->magenta) (1.0.2)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.2->magenta) (1.1.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.2->magenta) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.2->magenta) (0.3.1)
# Requirement already satisfied: soundfile>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.2->magenta) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.2->magenta) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.2->magenta) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.2->magenta) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      |████████████████████████████████| 944 kB 52.3 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.2->magenta) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.2->magenta) (3.0.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from mir-eval==0.7->magenta) (0.16.0)
# Requirement already satisfied: bokeh>=0.12.0 in /usr/local/lib/python3.7/dist-packages (from note-seq==0.0.3->magenta) (2.3.3)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from note-seq==0.0.3->magenta) (1.3.5)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from note-seq==0.0.3->magenta) (3.17.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from note-seq==0.0.3->magenta) (22.1.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from note-seq==0.0.3->magenta) (5.5.0)
# Requirement already satisfied: intervaltree>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from note-seq==0.0.3->magenta) (2.1.0)
# Collecting llvmlite<=0.33.0.dev0,>=0.31.0.dev0
#   Downloading llvmlite-0.32.1-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      |████████████████████████████████| 20.2 MB 1.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.49.1->magenta) (57.4.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image==0.19.3->magenta) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from scikit-image==0.19.3->magenta) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image==0.19.3->magenta) (2021.11.2)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (1.6.3)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 58.9 MB/s
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (0.26.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 59.8 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (4.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (1.47.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (14.0.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (0.2.0)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 72.4 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1->magenta) (1.1.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (0.6.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (1.9.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (0.3.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (4.64.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (2.23.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (0.10.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.6.0->magenta) (5.9.0)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.17.0->magenta) (1.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=0.12.0->note-seq==0.0.3->magenta) (3.13)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=0.12.0->note-seq==0.0.3->magenta) (2.11.3)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=0.12.0->note-seq==0.0.3->magenta) (5.1.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow==2.9.1->magenta) (1.5.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from intervaltree>=2.1.0->note-seq==0.0.3->magenta) (2.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=0.12.0->note-seq==0.0.3->magenta) (2.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->note-seq==0.0.3->magenta) (2022.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.6.0->magenta) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.6.0->magenta) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.6.0->magenta) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.6.0->magenta) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.7.2->magenta) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.9.0->librosa==0.7.2->magenta) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.9.0->librosa==0.7.2->magenta) (2.21)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta) (3.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->note-seq==0.0.3->magenta) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->note-seq==0.0.3->magenta) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->note-seq==0.0.3->magenta) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->note-seq==0.0.3->magenta) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->note-seq==0.0.3->magenta) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->note-seq==0.0.3->magenta) (5.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->note-seq==0.0.3->magenta) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->note-seq==0.0.3->magenta) (0.7.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tensorflow-datasets==4.6.0->magenta) (1.56.4)
# Building wheels for collected packages: librosa, mir-eval, pretty-midi, pygtrie, python-rtmidi
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.7.2-py3-none-any.whl size=1612902 sha256=b81b96dd857b29e5b953a49d80734ca7e01f81d5e06f4bd2b269ab2dfc74ee55
#   Stored in directory: /root/.cache/pip/wheels/18/9e/42/3224f85730f92fa2925f0b4fb6ef7f9c5431a64dfc77b95b39
#   Building wheel for mir-eval (setup.py) ... done
#   Created wheel for mir-eval: filename=mir_eval-0.7-py3-none-any.whl size=100721 sha256=80e6bc9d35da7839b3cf79c0b129e31a21cce644ff70592f48740900eb460982
#   Stored in directory: /root/.cache/pip/wheels/18/5a/46/d2527ff1fd975e1a793375e6ed763bfe4d3ea396b7cdc470eb
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591955 sha256=5f03ddcf92cf0dccc9b8a6216cc8360ac8d888efabb2f015ccb8d1a063004eb5
#   Stored in directory: /root/.cache/pip/wheels/ad/74/7c/a06473ca8dcb63efb98c1e67667ce39d52100f837835ea18fa
#   Building wheel for pygtrie (setup.py) ... done
#   Created wheel for pygtrie: filename=pygtrie-2.5.0-py3-none-any.whl size=20944 sha256=61381a8b3198a9dd8f02be17561bf2c20e231d44d27b8ef1441108a7aa791834
#   Stored in directory: /root/.cache/pip/wheels/d1/5b/c8/7791f519f0b9f7186bd7531fe8749a849934739069ee2f2a43
#   Building wheel for python-rtmidi (setup.py) ... done
#   Created wheel for python-rtmidi: filename=python_rtmidi-1.1.2-cp37-cp37m-linux_x86_64.whl size=391723 sha256=d13a82c791632b1ae4467102694199517a6a106ac8ebf2eaeab9791fd258ebb8
#   Stored in directory: /root/.cache/pip/wheels/ba/0c/e1/ccca9af1590f715067166c3199f6b639a26a152f61d4e79397
# Successfully built librosa mir-eval pretty-midi pygtrie python-rtmidi
# Installing collected packages: six, llvmlite, numba, Pillow, mido, tensorflow-estimator, tensorboard, pydub, pretty-midi, librosa, keras, imageio, gast, fonttools, flatbuffers, tf-slim, tensorflow-probability, tensorflow, sox, sk-video, scikit-image, python-rtmidi, pygtrie, note-seq, mir-eval, matplotlib, dm-sonnet, magenta
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.0
#     Uninstalling llvmlite-0.39.0:
#       Successfully uninstalled llvmlite-0.39.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.0
#     Uninstalling numba-0.56.0:
#       Successfully uninstalled numba-0.56.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.9.0
#     Uninstalling imageio-2.9.0:
#       Successfully uninstalled imageio-2.9.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow-probability
#     Found existing installation: tensorflow-probability 0.16.0
#     Uninstalling tensorflow-probability-0.16.0:
#       Successfully uninstalled tensorflow-probability-0.16.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.3
#     Uninstalling scikit-image-0.18.3:
#       Successfully uninstalled scikit-image-0.18.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed Pillow-9.2.0 dm-sonnet-2.0.0 flatbuffers-1.12 fonttools-4.34.4 gast-0.4.0 imageio-2.20.0 keras-2.9.0 librosa-0.7.2 llvmlite-0.32.1 magenta-2.1.4 matplotlib-3.5.2 mido-1.2.6 mir-eval-0.7 note-seq-0.0.3 numba-0.49.1 pretty-midi-0.2.9 pydub-0.25.1 pygtrie-2.5.0 python-rtmidi-1.1.2 scikit-image-0.19.3 six-1.16.0 sk-video-1.1.10 sox-1.4.1 tensorboard-2.9.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-probability-0.17.0 tf-slim-1.1.0

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------
# absl-py                       1.2.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# albumentations                1.2.1
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# asynctest                     0.13.0
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.1.0
# audioread                     2.1.9
# autograd                      1.4
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# blis                          0.7.8
# bokeh                         2.3.3
# branca                        0.5.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    4.2.4
# catalogue                     2.0.8
# certifi                       2022.6.15
# cffi                          1.15.1
# cftime                        1.6.1
# chardet                       3.0.4
# charset-normalizer            2.1.0
# click                         7.1.2
# clikit                        0.6.2
# cloudpickle                   1.3.0
# cmake                         3.22.6
# cmdstanpy                     1.0.4
# colorcet                      3.0.0
# colorlover                    0.3.0
# community                     1.0.0b1
# contextlib2                   0.5.5
# convertdate                   2.4.0
# crashtest                     0.3.1
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda111                  9.4.0
# cvxopt                        1.3.0
# cvxpy                         1.2.1
# cycler                        0.11.0
# cymem                         2.0.6
# Cython                        0.29.32
# daft                          0.0.4
# dask                          2.12.0
# datascience                   0.17.5
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# deprecat                      2.1.1
# descartes                     1.1.0
# dill                          0.3.5.1
# distributed                   1.25.3
# dlib                          19.24.0
# dm-sonnet                     2.0.0
# dm-tree                       0.1.7
# docutils                      0.17.1
# dopamine-rl                   1.0.5
# earthengine-api               0.1.317
# easydict                      1.9
# ecos                          2.0.10
# editdistance                  0.5.3
# en-core-web-sm                3.4.0
# entrypoints                   0.4
# ephem                         4.1.3
# et-xmlfile                    1.1.0
# etils                         0.6.0
# fa2                           0.3.5
# fastai                        2.7.7
# fastcore                      1.5.13
# fastdownload                  0.0.7
# fastdtw                       0.3.4
# fastjsonschema                2.16.1
# fastprogress                  1.0.3
# fastrlock                     0.8
# feather-format                0.4.1
# filelock                      3.7.1
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   1.12
# folium                        0.12.1.post1
# fonttools                     4.34.4
# frozenlist                    1.3.0
# future                        0.16.0
# gast                          0.4.0
# GDAL                          2.2.2
# gdown                         4.4.0
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.31.6
# google-api-python-client      1.12.11
# google-auth                   1.35.0
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.2
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.56.4
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      1.1.2
# grpcio                        1.47.0
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.17.3
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.14.2
# holoviews                     1.14.9
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# httpstan                      4.6.1
# humanize                      0.5.1
# hyperopt                      0.1.2
# idna                          2.10
# imageio                       2.20.0
# imagesize                     1.4.1
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.4.0
# importlib-metadata            4.12.0
# importlib-resources           5.9.0
# imutils                       0.5.4
# inflect                       2.1.0
# intel-openmp                  2022.1.0
# intervaltree                  2.1.0
# ipykernel                     4.10.1
# ipython                       5.5.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  1.1.0
# jax                           0.3.14
# jaxlib                        0.3.14+cuda11.cudnn805
# jedi                          0.18.1
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.1.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter                       1.0.0
# jupyter-client                5.3.5
# jupyter-console               5.2.0
# jupyter-core                  4.11.1
# jupyterlab-pygments           0.2.2
# jupyterlab-widgets            1.1.1
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.9.0
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.2.1
# langcodes                     3.3.0
# libclang                      14.0.6
# librosa                       0.7.2
# lightgbm                      2.2.3
# llvmlite                      0.32.1
# lmdb                          0.99
# LunarCalendar                 0.0.9
# lxml                          4.9.1
# magenta                       2.1.4
# Markdown                      3.4.1
# MarkupSafe                    2.0.1
# marshmallow                   3.17.0
# matplotlib                    3.5.2
# matplotlib-inline             0.1.3
# matplotlib-venn               0.11.7
# mido                          1.2.6
# mir-eval                      0.7
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.6.0
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.13.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.4
# multidict                     6.0.2
# multitasking                  0.0.11
# murmurhash                    1.0.7
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.6.6
# nbconvert                     5.6.1
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# netCDF4                       1.6.0
# networkx                      2.6.3
# nibabel                       3.0.2
# nltk                          3.7
# note-seq                      0.0.3
# notebook                      5.3.1
# numba                         0.49.1
# numexpr                       2.8.3
# numpy                         1.21.6
# oauth2client                  4.1.3
# oauthlib                      3.2.0
# okgrade                       0.4.3
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.6.0.66
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.2
# parso                         0.8.3
# pastel                        0.2.1
# pathlib                       1.0.1
# pathy                         0.6.2
# patsy                         0.5.2
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           21.1.3
# pip-tools                     6.2.0
# pkgutil-resolve-name          1.3.10
# plotly                        5.5.0
# plotnine                      0.6.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.1
# preshed                       3.0.6
# pretty-midi                   0.2.9
# prettytable                   3.3.0
# progressbar2                  3.38.0
# prometheus-client             0.14.1
# promise                       2.3
# prompt-toolkit                1.0.18
# prophet                       1.1
# protobuf                      3.17.3
# psutil                        5.4.8
# psycopg2                      2.9.3
# ptyprocess                    0.7.0
# py                            1.11.0
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycparser                     2.21
# pyct                          0.4.8
# pydantic                      1.9.1
# pydata-google-auth            1.4.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pydub                         0.25.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# pyglet                        1.5.0
# Pygments                      2.6.1
# pygobject                     3.26.1
# pygtrie                       2.5.0
# pylev                         1.4.0
# pymc3                         3.11.5
# PyMeeus                       0.5.11
# pymongo                       4.2.0
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.18.1
# pysimdjson                    3.2.0
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        3.3.0
# pytest                        3.6.4
# python-apt                    0.0.0
# python-chess                  0.23.11
# python-dateutil               2.8.2
# python-louvain                0.16
# python-rtmidi                 1.1.2
# python-slugify                6.1.2
# python-utils                  3.3.3
# pytz                          2022.1
# pyviz-comms                   2.2.0
# PyWavelets                    1.3.0
# PyYAML                        3.13
# pyzmq                         23.2.0
# qdldl                         0.1.5.post2
# qtconsole                     5.3.1
# QtPy                          2.1.0
# qudida                        0.0.4
# regex                         2022.6.2
# requests                      2.23.0
# requests-oauthlib             1.3.1
# resampy                       0.3.1
# rpy2                          3.4.5
# rsa                           4.9
# scikit-image                  0.19.3
# scikit-learn                  1.0.2
# scipy                         1.7.3
# screen-resolution-extra       0.0.0
# scs                           3.2.0
# seaborn                       0.11.2
# semver                        2.13.0
# Send2Trash                    1.8.0
# setuptools                    57.4.0
# setuptools-git                1.2
# Shapely                       1.8.2
# simplegeneric                 0.8.1
# six                           1.16.0
# sk-video                      1.1.10
# sklearn                       0.0
# sklearn-pandas                1.8.0
# smart-open                    5.2.1
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# SoundFile                     0.10.3.post1
# soupsieve                     2.3.2.post1
# sox                           1.4.1
# spacy                         3.4.1
# spacy-legacy                  3.0.9
# spacy-loggers                 1.0.3
# Sphinx                        1.8.6
# sphinxcontrib-serializinghtml 1.1.5
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.4.39
# sqlparse                      0.4.2
# srsly                         2.4.4
# statsmodels                   0.10.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.9.1
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.9.1
# tensorflow-datasets           4.6.0
# tensorflow-estimator          2.9.0
# tensorflow-gcs-config         2.8.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.26.0
# tensorflow-metadata           1.9.0
# tensorflow-probability        0.17.0
# termcolor                     1.1.0
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# tf-slim                       1.1.0
# Theano-PyMC                   1.1.2
# thinc                         8.1.0
# threadpoolctl                 3.1.0
# tifffile                      2021.11.2
# tinycss2                      1.1.1
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.12.0+cu113
# torchaudio                    0.12.0+cu113
# torchsummary                  1.5.1
# torchtext                     0.13.0
# torchvision                   0.13.0+cu113
# tornado                       5.1.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typer                         0.4.2
# typing-extensions             4.1.1
# tzlocal                       1.5.1
# ujson                         5.4.0
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.10.1
# wcwidth                       0.2.5
# webargs                       8.2.0
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.37.1
# widgetsnbextension            3.6.1
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        0.20.2
# xarray-einstats               0.2.2
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yarl                          1.8.1
# yellowbrick                   1.4
# zict                          2.2.0
# zipp                          3.8.1

# %% [markdown]
# # 2. 학습

# %%
sh = """
music_vae_train \
--config=groovae_4bar \
--run_dir=/tmp/music_vae/ \
--mode=train \
--num_steps=3000 \
"""
with open('script.sh', 'w') as file:
  file.write(sh)

# !bash script.sh
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2022-08-09 09:23:36.561548: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Building MusicVAE model with BidirectionalLstmEncoder, GrooveLstmDecoder, and hparams:
# {'max_seq_len': 64, 'z_size': 256, 'free_bits': 48, 'max_beta': 0.2, 'beta_rate': 0.0, 'batch_size': 512, 'grad_clip': 1.0, 'clip_mode': 'global_norm', 'grad_norm_clip_to_zero': 10000, 'learning_rate': 0.001, 'decay_rate': 0.9999, 'min_learning_rate': 1e-05, 'conditional': True, 'dec_rnn_size': [256, 256], 'enc_rnn_size': [512], 'dropout_keep_prob': 0.3, 'sampling_schedule': 'constant', 'sampling_rate': 0.0, 'use_cudnn': False, 'residual_encoder': False, 'residual_decoder': False, 'control_preprocessing_rnn_size': [256]}
# I0809 09:23:36.577061 140316860209024 base_model.py:152] Building MusicVAE model with BidirectionalLstmEncoder, GrooveLstmDecoder, and hparams:
# {'max_seq_len': 64, 'z_size': 256, 'free_bits': 48, 'max_beta': 0.2, 'beta_rate': 0.0, 'batch_size': 512, 'grad_clip': 1.0, 'clip_mode': 'global_norm', 'grad_norm_clip_to_zero': 10000, 'learning_rate': 0.001, 'decay_rate': 0.9999, 'min_learning_rate': 1e-05, 'conditional': True, 'dec_rnn_size': [256, 256], 'enc_rnn_size': [512], 'dropout_keep_prob': 0.3, 'sampling_schedule': 'constant', 'sampling_rate': 0.0, 'use_cudnn': False, 'residual_encoder': False, 'residual_decoder': False, 'control_preprocessing_rnn_size': [256]}
# INFO:tensorflow:
# Encoder Cells (bidirectional):
#   units: [512]
#
# I0809 09:23:36.583398 140316860209024 lstm_models.py:78]
# Encoder Cells (bidirectional):
#   units: [512]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0809 09:23:36.591533 140316860209024 legacy_cells.py:1109] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0809 09:23:36.598897 140316860209024 legacy_cells.py:1109] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:
# Decoder Cells:
#   units: [256, 256]
#
# I0809 09:23:36.599309 140316860209024 lstm_models.py:224]
# Decoder Cells:
#   units: [256, 256]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0809 09:23:36.614782 140316860209024 legacy_cells.py:1109] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:Reading examples from TFDS: groove/4bar-midionly
# I0809 09:23:36.615254 140316860209024 data.py:1832] Reading examples from TFDS: groove/4bar-midionly
# 2022-08-09 09:23:36.729737: W tensorflow/core/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# I0809 09:23:37.232129 140316860209024 dataset_info.py:491] Load dataset info from gs://tfds-data/datasets/groove/4bar-midionly/2.0.1
# I0809 09:23:38.092645 140316860209024 dataset_info.py:552] Field info.description from disk and from code do not match. Keeping the one from code.
# I0809 09:23:38.092861 140316860209024 dataset_info.py:552] Field info.config_name from disk and from code do not match. Keeping the one from code.
# I0809 09:23:38.092950 140316860209024 dataset_info.py:552] Field info.config_description from disk and from code do not match. Keeping the one from code.
# I0809 09:23:38.093026 140316860209024 dataset_info.py:552] Field info.citation from disk and from code do not match. Keeping the one from code.
# I0809 09:23:38.093170 140316860209024 dataset_info.py:552] Field info.splits from disk and from code do not match. Keeping the one from code.
# I0809 09:23:38.093252 140316860209024 dataset_info.py:552] Field info.module_name from disk and from code do not match. Keeping the one from code.
# I0809 09:23:38.160512 140316860209024 dataset_builder.py:383] Reusing dataset groove (gs://tfds-data/datasets/groove/4bar-midionly/2.0.1)
# I0809 09:23:38.160732 140316860209024 logging_logger.py:45] Constructing tf.data.Dataset groove for split train, from gs://tfds-data/datasets/groove/4bar-midionly/2.0.1
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0809 09:23:38.632989 140316860209024 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:473: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# W0809 09:23:38.649691 140316860209024 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:473: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/rnn.py:446: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0809 09:23:38.650052 140316860209024 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/rnn.py:446: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:750: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   self._names["W"], [input_size + self._num_units, self._num_units * 4])
# /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:753: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   initializer=tf.constant_initializer(0.0))
# /usr/local/lib/python3.7/dist-packages/magenta/models/music_vae/base_model.py:199: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_initializer=tf.random_normal_initializer(stddev=0.001))
# /usr/local/lib/python3.7/dist-packages/magenta/models/music_vae/base_model.py:205: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_initializer=tf.random_normal_initializer(stddev=0.001))
# /usr/local/lib/python3.7/dist-packages/magenta/models/music_vae/lstm_utils.py:99: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   name=name),
# INFO:tensorflow:Create CheckpointSaverHook.
# I0809 09:23:46.529699 140316860209024 basic_session_run_hooks.py:558] Create CheckpointSaverHook.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0809 09:23:47.633681 140316860209024 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Graph was finalized.
# I0809 09:23:47.727156 140316860209024 monitored_session.py:243] Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# I0809 09:23:48.181712 140316860209024 session_manager.py:527] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0809 09:23:48.240128 140316860209024 session_manager.py:530] Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# I0809 09:23:52.192939 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/music_vae/train/model.ckpt.
# I0809 09:23:52.193171 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 0 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-0.index
# I0809 09:23:53.015059 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-0.index
# INFO:tensorflow:0
# I0809 09:23:53.015281 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-0.data-00000-of-00001
# I0809 09:23:53.015367 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-0.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:23:53.015455 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-0.meta
# I0809 09:23:53.015523 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-0.meta
# INFO:tensorflow:51800
# I0809 09:23:53.015591 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# I0809 09:23:53.015782 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:global_step = 0, loss = 566.6223
# I0809 09:24:39.299430 140316860209024 basic_session_run_hooks.py:266] global_step = 0, loss = 566.6223
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4...
# I0809 09:24:53.066636 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 4...
# INFO:tensorflow:Saving checkpoints for 4 into /tmp/music_vae/train/model.ckpt.
# I0809 09:24:53.066944 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 4 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-4.meta
# I0809 09:24:54.095538 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-4.meta
# INFO:tensorflow:2800
# I0809 09:24:54.095771 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-4.index
# I0809 09:24:54.097748 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-4.index
# INFO:tensorflow:2800
# I0809 09:24:54.097947 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-4.data-00000-of-00001
# I0809 09:24:54.098045 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-4.data-00000-of-00001
# INFO:tensorflow:51800
# I0809 09:24:54.098134 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4...
# I0809 09:24:54.098315 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 4...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 19...
# I0809 09:25:54.430284 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 19...
# INFO:tensorflow:Saving checkpoints for 19 into /tmp/music_vae/train/model.ckpt.
# I0809 09:25:54.435762 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 19 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-19.data-00000-of-00001
# I0809 09:25:55.378365 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-19.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:25:55.378584 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-19.index
# I0809 09:25:55.378672 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-19.index
# INFO:tensorflow:49000
# I0809 09:25:55.378756 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-19.meta
# I0809 09:25:55.378862 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-19.meta
# INFO:tensorflow:51800
# I0809 09:25:55.378942 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 19...
# I0809 09:25:55.379104 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 19...
# INFO:tensorflow:global_step/sec: 0.943654
# I0809 09:26:25.269751 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 0.943654
# INFO:tensorflow:global_step = 100, loss = 218.51599 (105.971 sec)
# I0809 09:26:25.270786 140316860209024 basic_session_run_hooks.py:264] global_step = 100, loss = 218.51599 (105.971 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 197...
# I0809 09:26:54.710278 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 197...
# INFO:tensorflow:Saving checkpoints for 197 into /tmp/music_vae/train/model.ckpt.
# I0809 09:26:54.710519 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 197 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-197.data-00000-of-00001
# I0809 09:26:55.440536 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-197.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:26:55.440777 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-197.index
# I0809 09:26:55.440899 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-197.index
# INFO:tensorflow:49000
# I0809 09:26:55.440984 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-197.meta
# I0809 09:26:55.441052 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-197.meta
# INFO:tensorflow:51800
# I0809 09:26:55.441122 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 197...
# I0809 09:26:55.441313 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 197...
# INFO:tensorflow:global_step/sec: 3.18436
# I0809 09:26:56.673200 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.18436
# INFO:tensorflow:global_step = 200, loss = 197.04138 (31.403 sec)
# I0809 09:26:56.674086 140316860209024 basic_session_run_hooks.py:264] global_step = 200, loss = 197.04138 (31.403 sec)
# INFO:tensorflow:global_step/sec: 3.21671
# I0809 09:27:27.760909 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.21671
# INFO:tensorflow:global_step = 300, loss = 171.21938 (31.088 sec)
# I0809 09:27:27.762065 140316860209024 basic_session_run_hooks.py:264] global_step = 300, loss = 171.21938 (31.088 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 389...
# I0809 09:27:55.008201 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 389...
# INFO:tensorflow:Saving checkpoints for 389 into /tmp/music_vae/train/model.ckpt.
# I0809 09:27:55.008439 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 389 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-389.index
# I0809 09:27:55.754130 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-389.index
# INFO:tensorflow:0
# I0809 09:27:55.754356 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-389.data-00000-of-00001
# I0809 09:27:55.754442 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-389.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:27:55.754520 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-389.meta
# I0809 09:27:55.754585 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-389.meta
# INFO:tensorflow:51800
# I0809 09:27:55.754653 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 389...
# I0809 09:27:55.754841 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 389...
# INFO:tensorflow:global_step/sec: 3.15959
# I0809 09:27:59.410569 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.15959
# INFO:tensorflow:global_step = 400, loss = 168.09479 (31.649 sec)
# I0809 09:27:59.411548 140316860209024 basic_session_run_hooks.py:264] global_step = 400, loss = 168.09479 (31.649 sec)
# INFO:tensorflow:global_step/sec: 3.25843
# I0809 09:28:30.100224 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.25843
# INFO:tensorflow:global_step = 500, loss = 160.74548 (30.690 sec)
# I0809 09:28:30.101248 140316860209024 basic_session_run_hooks.py:264] global_step = 500, loss = 160.74548 (30.690 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 583...
# I0809 09:28:55.242213 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 583...
# INFO:tensorflow:Saving checkpoints for 583 into /tmp/music_vae/train/model.ckpt.
# I0809 09:28:55.242447 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 583 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-583.index
# I0809 09:28:55.965604 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-583.index
# INFO:tensorflow:0
# I0809 09:28:55.965867 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-583.meta
# I0809 09:28:55.965972 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-583.meta
# INFO:tensorflow:2800
# I0809 09:28:55.966071 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-583.data-00000-of-00001
# I0809 09:28:55.966150 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-583.data-00000-of-00001
# INFO:tensorflow:51800
# I0809 09:28:55.966219 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 583...
# I0809 09:28:55.966398 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 583...
# INFO:tensorflow:global_step/sec: 3.18382
# I0809 09:29:01.509045 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.18382
# INFO:tensorflow:global_step = 600, loss = 160.70448 (31.409 sec)
# I0809 09:29:01.509969 140316860209024 basic_session_run_hooks.py:264] global_step = 600, loss = 160.70448 (31.409 sec)
# INFO:tensorflow:global_step/sec: 3.27578
# I0809 09:29:32.036163 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27578
# INFO:tensorflow:global_step = 700, loss = 157.40973 (30.527 sec)
# I0809 09:29:32.037056 140316860209024 basic_session_run_hooks.py:264] global_step = 700, loss = 157.40973 (30.527 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 777...
# I0809 09:29:55.531820 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 777...
# INFO:tensorflow:Saving checkpoints for 777 into /tmp/music_vae/train/model.ckpt.
# I0809 09:29:55.532054 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 777 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-777.meta
# I0809 09:29:56.262908 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-777.meta
# INFO:tensorflow:2800
# I0809 09:29:56.263117 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-777.index
# I0809 09:29:56.263197 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-777.index
# INFO:tensorflow:2800
# I0809 09:29:56.263270 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-777.data-00000-of-00001
# I0809 09:29:56.263340 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-777.data-00000-of-00001
# INFO:tensorflow:51800
# I0809 09:29:56.263407 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 777...
# I0809 09:29:56.263591 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 777...
# INFO:tensorflow:global_step/sec: 3.16813
# I0809 09:30:03.600557 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.16813
# INFO:tensorflow:global_step = 800, loss = 154.61626 (31.565 sec)
# I0809 09:30:03.601558 140316860209024 basic_session_run_hooks.py:264] global_step = 800, loss = 154.61626 (31.565 sec)
# INFO:tensorflow:global_step/sec: 3.27259
# I0809 09:30:34.157406 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27259
# INFO:tensorflow:global_step = 900, loss = 144.73453 (30.557 sec)
# I0809 09:30:34.158362 140316860209024 basic_session_run_hooks.py:264] global_step = 900, loss = 144.73453 (30.557 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 972...
# I0809 09:30:55.825868 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 972...
# INFO:tensorflow:Saving checkpoints for 972 into /tmp/music_vae/train/model.ckpt.
# I0809 09:30:55.826083 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 972 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-972.index
# I0809 09:30:56.555993 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-972.index
# INFO:tensorflow:0
# I0809 09:30:56.556209 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-972.meta
# I0809 09:30:56.556294 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-972.meta
# INFO:tensorflow:2800
# I0809 09:30:56.556378 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-972.data-00000-of-00001
# I0809 09:30:56.556448 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-972.data-00000-of-00001
# INFO:tensorflow:51800
# I0809 09:30:56.556518 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 972...
# I0809 09:30:56.556686 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 972...
# INFO:tensorflow:global_step/sec: 3.19615
# I0809 09:31:05.445035 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.19615
# INFO:tensorflow:global_step = 1000, loss = 137.40196 (31.287 sec)
# I0809 09:31:05.445837 140316860209024 basic_session_run_hooks.py:264] global_step = 1000, loss = 137.40196 (31.287 sec)
# INFO:tensorflow:global_step/sec: 3.27312
# I0809 09:31:35.996943 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27312
# INFO:tensorflow:global_step = 1100, loss = 135.43517 (30.552 sec)
# I0809 09:31:35.997876 140316860209024 basic_session_run_hooks.py:264] global_step = 1100, loss = 135.43517 (30.552 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1166...
# I0809 09:31:56.106034 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 1166...
# INFO:tensorflow:Saving checkpoints for 1166 into /tmp/music_vae/train/model.ckpt.
# I0809 09:31:56.106292 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 1166 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1166.index
# I0809 09:31:56.989778 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1166.index
# INFO:tensorflow:0
# I0809 09:31:56.990020 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1166.data-00000-of-00001
# I0809 09:31:56.990102 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1166.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:31:56.990178 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1166.meta
# I0809 09:31:56.990243 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1166.meta
# INFO:tensorflow:51800
# I0809 09:31:56.990313 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1166...
# I0809 09:31:56.990491 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 1166...
# INFO:tensorflow:global_step/sec: 3.15201
# I0809 09:32:07.722765 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.15201
# INFO:tensorflow:global_step = 1200, loss = 134.07675 (31.726 sec)
# I0809 09:32:07.723604 140316860209024 basic_session_run_hooks.py:264] global_step = 1200, loss = 134.07675 (31.726 sec)
# INFO:tensorflow:global_step/sec: 3.27482
# I0809 09:32:38.258870 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27482
# INFO:tensorflow:global_step = 1300, loss = 132.22372 (30.536 sec)
# I0809 09:32:38.259691 140316860209024 basic_session_run_hooks.py:264] global_step = 1300, loss = 132.22372 (30.536 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1360...
# I0809 09:32:56.309661 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 1360...
# INFO:tensorflow:Saving checkpoints for 1360 into /tmp/music_vae/train/model.ckpt.
# I0809 09:32:56.309905 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 1360 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1360.data-00000-of-00001
# I0809 09:32:57.044581 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1360.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:32:57.044888 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1360.index
# I0809 09:32:57.045002 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1360.index
# INFO:tensorflow:49000
# I0809 09:32:57.045093 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1360.meta
# I0809 09:32:57.045172 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1360.meta
# INFO:tensorflow:51800
# I0809 09:32:57.045254 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1360...
# I0809 09:32:57.045443 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 1360...
# INFO:tensorflow:global_step/sec: 3.19277
# I0809 09:33:09.579608 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.19277
# INFO:tensorflow:global_step = 1400, loss = 124.4659 (31.321 sec)
# I0809 09:33:09.580551 140316860209024 basic_session_run_hooks.py:264] global_step = 1400, loss = 124.4659 (31.321 sec)
# INFO:tensorflow:global_step/sec: 3.27531
# I0809 09:33:40.111044 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27531
# INFO:tensorflow:global_step = 1500, loss = 124.397316 (30.531 sec)
# I0809 09:33:40.111917 140316860209024 basic_session_run_hooks.py:264] global_step = 1500, loss = 124.397316 (30.531 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1555...
# I0809 09:33:56.535563 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 1555...
# INFO:tensorflow:Saving checkpoints for 1555 into /tmp/music_vae/train/model.ckpt.
# I0809 09:33:56.535903 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 1555 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1555.index
# I0809 09:33:57.266734 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1555.index
# INFO:tensorflow:0
# I0809 09:33:57.266976 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1555.data-00000-of-00001
# I0809 09:33:57.267064 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1555.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:33:57.267142 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1555.meta
# I0809 09:33:57.267207 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1555.meta
# INFO:tensorflow:51800
# I0809 09:33:57.267273 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1555...
# I0809 09:33:57.267444 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 1555...
# INFO:tensorflow:global_step/sec: 3.1678
# I0809 09:34:11.678681 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.1678
# INFO:tensorflow:global_step = 1600, loss = 121.80838 (31.568 sec)
# I0809 09:34:11.679725 140316860209024 basic_session_run_hooks.py:264] global_step = 1600, loss = 121.80838 (31.568 sec)
# INFO:tensorflow:global_step/sec: 3.27598
# I0809 09:34:42.203907 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27598
# INFO:tensorflow:global_step = 1700, loss = 120.51511 (30.525 sec)
# I0809 09:34:42.204901 140316860209024 basic_session_run_hooks.py:264] global_step = 1700, loss = 120.51511 (30.525 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1749...
# I0809 09:34:56.815024 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 1749...
# INFO:tensorflow:Saving checkpoints for 1749 into /tmp/music_vae/train/model.ckpt.
# I0809 09:34:56.815242 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 1749 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1749.data-00000-of-00001
# I0809 09:34:57.537433 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1749.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:34:57.537660 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1749.meta
# I0809 09:34:57.537744 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1749.meta
# INFO:tensorflow:51800
# I0809 09:34:57.537837 140316860209024 saver.py:93] 51800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1749.index
# I0809 09:34:57.537909 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1749.index
# INFO:tensorflow:51800
# I0809 09:34:57.537976 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1749...
# I0809 09:34:57.538146 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 1749...
# INFO:tensorflow:global_step/sec: 3.20194
# I0809 09:35:13.435001 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.20194
# INFO:tensorflow:global_step = 1800, loss = 118.093475 (31.231 sec)
# I0809 09:35:13.436040 140316860209024 basic_session_run_hooks.py:264] global_step = 1800, loss = 118.093475 (31.231 sec)
# INFO:tensorflow:global_step/sec: 3.26997
# I0809 09:35:44.016326 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.26997
# INFO:tensorflow:global_step = 1900, loss = 114.356026 (30.581 sec)
# I0809 09:35:44.017366 140316860209024 basic_session_run_hooks.py:264] global_step = 1900, loss = 114.356026 (30.581 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1943...
# I0809 09:35:56.858407 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 1943...
# INFO:tensorflow:Saving checkpoints for 1943 into /tmp/music_vae/train/model.ckpt.
# I0809 09:35:56.858628 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 1943 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1943.data-00000-of-00001
# I0809 09:35:57.597210 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1943.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:35:57.597447 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1943.meta
# I0809 09:35:57.597539 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1943.meta
# INFO:tensorflow:51800
# I0809 09:35:57.597620 140316860209024 saver.py:93] 51800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-1943.index
# I0809 09:35:57.597694 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-1943.index
# INFO:tensorflow:51800
# I0809 09:35:57.597765 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1943...
# I0809 09:35:57.597972 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 1943...
# INFO:tensorflow:global_step/sec: 3.16023
# I0809 09:36:15.659572 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.16023
# INFO:tensorflow:global_step = 2000, loss = 113.62367 (31.643 sec)
# I0809 09:36:15.660571 140316860209024 basic_session_run_hooks.py:264] global_step = 2000, loss = 113.62367 (31.643 sec)
# INFO:tensorflow:global_step/sec: 3.25978
# I0809 09:36:46.336478 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.25978
# INFO:tensorflow:global_step = 2100, loss = 110.59675 (30.677 sec)
# I0809 09:36:46.337504 140316860209024 basic_session_run_hooks.py:264] global_step = 2100, loss = 110.59675 (30.677 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2136...
# I0809 09:36:57.075685 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 2136...
# INFO:tensorflow:Saving checkpoints for 2136 into /tmp/music_vae/train/model.ckpt.
# I0809 09:36:57.075918 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 2136 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2136.meta
# I0809 09:36:57.812093 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2136.meta
# INFO:tensorflow:2800
# I0809 09:36:57.812322 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2136.index
# I0809 09:36:57.812407 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2136.index
# INFO:tensorflow:2800
# I0809 09:36:57.812483 140316860209024 saver.py:93] 2800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2136.data-00000-of-00001
# I0809 09:36:57.812546 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2136.data-00000-of-00001
# INFO:tensorflow:51800
# I0809 09:36:57.812613 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2136...
# I0809 09:36:57.812785 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 2136...
# INFO:tensorflow:global_step/sec: 3.19147
# I0809 09:37:17.670023 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.19147
# INFO:tensorflow:global_step = 2200, loss = 110.664055 (31.333 sec)
# I0809 09:37:17.670987 140316860209024 basic_session_run_hooks.py:264] global_step = 2200, loss = 110.664055 (31.333 sec)
# INFO:tensorflow:global_step/sec: 3.26533
# I0809 09:37:48.294827 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.26533
# INFO:tensorflow:global_step = 2300, loss = 106.83048 (30.625 sec)
# I0809 09:37:48.295895 140316860209024 basic_session_run_hooks.py:264] global_step = 2300, loss = 106.83048 (30.625 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2330...
# I0809 09:37:57.176714 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 2330...
# INFO:tensorflow:Saving checkpoints for 2330 into /tmp/music_vae/train/model.ckpt.
# I0809 09:37:57.176952 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 2330 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2330.data-00000-of-00001
# I0809 09:37:57.915356 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2330.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:37:57.915648 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2330.meta
# I0809 09:37:57.915772 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2330.meta
# INFO:tensorflow:51800
# I0809 09:37:57.915903 140316860209024 saver.py:93] 51800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2330.index
# I0809 09:37:57.915992 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2330.index
# INFO:tensorflow:51800
# I0809 09:37:57.916079 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2330...
# I0809 09:37:57.916291 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 2330...
# INFO:tensorflow:global_step/sec: 3.15208
# I0809 09:38:20.019864 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.15208
# INFO:tensorflow:global_step = 2400, loss = 106.19159 (31.725 sec)
# I0809 09:38:20.020880 140316860209024 basic_session_run_hooks.py:264] global_step = 2400, loss = 106.19159 (31.725 sec)
# INFO:tensorflow:global_step/sec: 3.26373
# I0809 09:38:50.659619 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.26373
# INFO:tensorflow:global_step = 2500, loss = 104.24798 (30.640 sec)
# I0809 09:38:50.660651 140316860209024 basic_session_run_hooks.py:264] global_step = 2500, loss = 104.24798 (30.640 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2523...
# I0809 09:38:57.369589 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 2523...
# INFO:tensorflow:Saving checkpoints for 2523 into /tmp/music_vae/train/model.ckpt.
# I0809 09:38:57.369812 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 2523 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2523.index
# I0809 09:38:58.076516 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2523.index
# INFO:tensorflow:0
# I0809 09:38:58.076763 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2523.data-00000-of-00001
# I0809 09:38:58.076888 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2523.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:38:58.076974 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2523.meta
# I0809 09:38:58.077050 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2523.meta
# INFO:tensorflow:51800
# I0809 09:38:58.077122 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2523...
# I0809 09:38:58.077302 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 2523...
# INFO:tensorflow:global_step/sec: 3.20009
# I0809 09:39:21.908770 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.20009
# INFO:tensorflow:global_step = 2600, loss = 101.07965 (31.249 sec)
# I0809 09:39:21.909755 140316860209024 basic_session_run_hooks.py:264] global_step = 2600, loss = 101.07965 (31.249 sec)
# INFO:tensorflow:global_step/sec: 3.27207
# I0809 09:39:52.470496 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.27207
# INFO:tensorflow:global_step = 2700, loss = 100.77072 (30.562 sec)
# I0809 09:39:52.471521 140316860209024 basic_session_run_hooks.py:264] global_step = 2700, loss = 100.77072 (30.562 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2718...
# I0809 09:39:57.656724 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 2718...
# INFO:tensorflow:Saving checkpoints for 2718 into /tmp/music_vae/train/model.ckpt.
# I0809 09:39:57.656957 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 2718 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2718.index
# I0809 09:39:58.380327 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2718.index
# INFO:tensorflow:0
# I0809 09:39:58.380551 140316860209024 saver.py:93] 0
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2718.data-00000-of-00001
# I0809 09:39:58.380636 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2718.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:39:58.380719 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2718.meta
# I0809 09:39:58.380792 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2718.meta
# INFO:tensorflow:51800
# I0809 09:39:58.380890 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2718...
# I0809 09:39:58.381095 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 2718...
# INFO:tensorflow:global_step/sec: 3.197
# I0809 09:40:23.749853 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.197
# INFO:tensorflow:global_step = 2800, loss = 98.863014 (31.279 sec)
# I0809 09:40:23.750804 140316860209024 basic_session_run_hooks.py:264] global_step = 2800, loss = 98.863014 (31.279 sec)
# INFO:tensorflow:global_step/sec: 3.25014
# I0809 09:40:54.517729 140316860209024 basic_session_run_hooks.py:717] global_step/sec: 3.25014
# INFO:tensorflow:global_step = 2900, loss = 100.61368 (30.768 sec)
# I0809 09:40:54.518672 140316860209024 basic_session_run_hooks.py:264] global_step = 2900, loss = 100.61368 (30.768 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2912...
# I0809 09:40:57.885385 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 2912...
# INFO:tensorflow:Saving checkpoints for 2912 into /tmp/music_vae/train/model.ckpt.
# I0809 09:40:57.885620 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 2912 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2912.data-00000-of-00001
# I0809 09:40:58.607236 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2912.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:40:58.607464 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2912.meta
# I0809 09:40:58.607551 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2912.meta
# INFO:tensorflow:51800
# I0809 09:40:58.607632 140316860209024 saver.py:93] 51800
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-2912.index
# I0809 09:40:58.607697 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-2912.index
# INFO:tensorflow:51800
# I0809 09:40:58.607763 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2912...
# I0809 09:40:58.607947 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 2912...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3000...
# I0809 09:41:25.418047 140316860209024 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 3000...
# INFO:tensorflow:Saving checkpoints for 3000 into /tmp/music_vae/train/model.ckpt.
# I0809 09:41:25.418249 140316860209024 basic_session_run_hooks.py:633] Saving checkpoints for 3000 into /tmp/music_vae/train/model.ckpt.
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-3000.data-00000-of-00001
# I0809 09:41:26.124235 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-3000.data-00000-of-00001
# INFO:tensorflow:49000
# I0809 09:41:26.124455 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-3000.index
# I0809 09:41:26.124541 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-3000.index
# INFO:tensorflow:49000
# I0809 09:41:26.124616 140316860209024 saver.py:93] 49000
# INFO:tensorflow:/tmp/music_vae/train/model.ckpt-3000.meta
# I0809 09:41:26.124680 140316860209024 saver.py:90] /tmp/music_vae/train/model.ckpt-3000.meta
# INFO:tensorflow:51800
# I0809 09:41:26.124746 140316860209024 saver.py:93] 51800
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3000...
# I0809 09:41:26.124942 140316860209024 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 3000...

# %% [markdown]
# # 3. 샘플링

# %%
sh = """
music_vae_generate \
--config=groovae_4bar \
--run_dir=/tmp/music_vae/ \
--mode=sample \
--num_outputs=5 \
--output_dir=/tmp/music_vae/generated
"""
with open('script.sh', 'w') as file:
  file.write(sh)

# !bash script.sh
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:Loading model...
# I0809 10:01:49.515034 140638096705408 music_vae_generate.py:149] Loading model...
# INFO:tensorflow:Building MusicVAE model with BidirectionalLstmEncoder, GrooveLstmDecoder, and hparams:
# {'max_seq_len': 64, 'z_size': 256, 'free_bits': 48, 'max_beta': 0.2, 'beta_rate': 0.0, 'batch_size': 5, 'grad_clip': 1.0, 'clip_mode': 'global_norm', 'grad_norm_clip_to_zero': 10000, 'learning_rate': 0.001, 'decay_rate': 0.9999, 'min_learning_rate': 1e-05, 'conditional': True, 'dec_rnn_size': [256, 256], 'enc_rnn_size': [512], 'dropout_keep_prob': 0.3, 'sampling_schedule': 'constant', 'sampling_rate': 0.0, 'use_cudnn': False, 'residual_encoder': False, 'residual_decoder': False, 'control_preprocessing_rnn_size': [256]}
# I0809 10:01:49.517171 140638096705408 base_model.py:152] Building MusicVAE model with BidirectionalLstmEncoder, GrooveLstmDecoder, and hparams:
# {'max_seq_len': 64, 'z_size': 256, 'free_bits': 48, 'max_beta': 0.2, 'beta_rate': 0.0, 'batch_size': 5, 'grad_clip': 1.0, 'clip_mode': 'global_norm', 'grad_norm_clip_to_zero': 10000, 'learning_rate': 0.001, 'decay_rate': 0.9999, 'min_learning_rate': 1e-05, 'conditional': True, 'dec_rnn_size': [256, 256], 'enc_rnn_size': [512], 'dropout_keep_prob': 0.3, 'sampling_schedule': 'constant', 'sampling_rate': 0.0, 'use_cudnn': False, 'residual_encoder': False, 'residual_decoder': False, 'control_preprocessing_rnn_size': [256]}
# INFO:tensorflow:
# Encoder Cells (bidirectional):
#   units: [512]
#
# I0809 10:01:49.523284 140638096705408 lstm_models.py:78]
# Encoder Cells (bidirectional):
#   units: [512]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0809 10:01:49.530984 140638096705408 legacy_cells.py:1109] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0809 10:01:49.538349 140638096705408 legacy_cells.py:1109] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:
# Decoder Cells:
#   units: [256, 256]
#
# I0809 10:01:49.538701 140638096705408 lstm_models.py:224]
# Decoder Cells:
#   units: [256, 256]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0809 10:01:49.552943 140638096705408 legacy_cells.py:1109] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# /usr/local/lib/python3.7/dist-packages/magenta/models/music_vae/lstm_utils.py:99: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   name=name),
# /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:750: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   self._names["W"], [input_size + self._num_units, self._num_units * 4])
# /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:753: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   initializer=tf.constant_initializer(0.0))
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0809 10:01:50.130341 140638096705408 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:473: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# W0809 10:01:50.131515 140638096705408 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/magenta/contrib/rnn.py:473: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/rnn.py:446: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0809 10:01:50.131851 140638096705408 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/rnn.py:446: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# /usr/local/lib/python3.7/dist-packages/magenta/models/music_vae/base_model.py:199: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_initializer=tf.random_normal_initializer(stddev=0.001))
# /usr/local/lib/python3.7/dist-packages/magenta/models/music_vae/base_model.py:205: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_initializer=tf.random_normal_initializer(stddev=0.001))
# 2022-08-09 10:01:51.191644: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Restoring parameters from /tmp/music_vae/train/model.ckpt-3000
# I0809 10:01:51.209186 140638096705408 saver.py:1412] Restoring parameters from /tmp/music_vae/train/model.ckpt-3000
# INFO:tensorflow:Sampling...
# I0809 10:01:51.258491 140638096705408 music_vae_generate.py:169] Sampling...
# INFO:tensorflow:Outputting 5 files as `/tmp/music_vae/generated/groovae_4bar_sample_2022-08-09_100149-*-of-005.mid`...
# I0809 10:01:51.888500 140638096705408 music_vae_generate.py:179] Outputting 5 files as `/tmp/music_vae/generated/groovae_4bar_sample_2022-08-09_100149-*-of-005.mid`...
# INFO:tensorflow:Done.
# I0809 10:01:51.907356 140638096705408 music_vae_generate.py:183] Done.
